# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("heart_disease_cleaned.csv")

# %%
ds
# Out:
#      Unnamed: 0  age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0             0   67    1   0     176.0  148.0    1        0    137.5      1
# 1             1   57    1   1     155.0  551.0    0        1     98.0      1
# 2             2   43    1   0     125.0  519.0    1        0    113.0      1
# 3             3   71    0   0     123.0  285.0    0        2    156.0      0
# 4             4   36    0   0     122.0  488.0    1        1    137.5      1
# ..          ...  ...  ...  ..       ...    ...  ...      ...      ...    ...
# 448         494   38    0   0     153.0  539.0    1        1     91.0      0
# 449         495   47    1   1     147.0  239.0    1        2    105.0      1
# 450         496   60    1   2      98.0  270.0    1        0    100.0      1
# 451         497   29    1   2     138.0  353.5    1        0    127.0      0
# 452         499   73    1   3     124.0  428.0    0        0     89.0      1
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    453 non-null    int64
#  1   age           453 non-null    int64
#  2   sex           453 non-null    int64
#  3   cp            453 non-null    int64
#  4   trestbps      453 non-null    float64
#  5   chol          453 non-null    float64
#  6   fbs           453 non-null    int64
#  7   restecg       453 non-null    int64
#  8   thalach       453 non-null    float64
#  9   exang         453 non-null    int64
#  10  oldpeak       453 non-null    float64
#  11  slope         453 non-null    int64
#  12  ca            453 non-null    int64
#  13  target        453 non-null    float64
#  14  thal_encoded  453 non-null    int64
# dtypes: float64(5), int64(10)
# memory usage: 53.2 KB

# %%
if 'unnamed:0' in ds.columns:
    ds = ds.drop(columns=['unnamed:0'])

# %%
#target variables distribution
plt.figure(figsize=(6,4))
sns.countplot(x='target',data = ds)
plt.title('Heart Disease Presence(Target)')
plt.xlabel('Target(0:No Disease ,1:Disease)')
plt.ylabel('Count')
plt.show()

# %%
# age distubution
plt.figure(figsize=(6, 4))
sns.histplot(ds['age'], kde=True, bins=15)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Cholesterol Distribution

plt.figure(figsize=(6, 4))
sns.histplot(ds['chol'], kde=True, bins=20)
plt.title('Cholesterol Level Distribution')
plt.xlabel('Cholesterol (mg/dL)')
plt.ylabel('Frequency')
plt.show()

# %%
# Resting Blood Pressure (trestbps)

plt.figure(figsize=(6, 4))
sns.boxplot(x='target', y='trestbps', data=ds)
plt.title('Resting Blood Pressure vs Heart Disease')
plt.show()

# %%
# Maximum Heart Rate (thalach)

plt.figure(figsize=(6, 4))
sns.boxplot(x='target', y='thalach', data=ds)
plt.title('Max Heart Rate vs Heart Disease')
plt.show()

# %%
# Count Plot for Sex

plt.figure(figsize=(6, 4))
sns.countplot(x='sex', data=df, hue='target')
plt.title('Heart Disease Count by Sex (0: Female, 1: Male)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 # Count Plot for Sex
#       3 plt.figure(figsize=(6, 4))
# ----> 4 sns.countplot(x='sex', data=df, hue='target')
#       5 plt.title('Heart Disease Count by Sex (0: Female, 1: Male)')
#       6 plt.show()
#
# NameError: name 'df' is not defined
